# %% [markdown]
# #  My Jupyter Notebook on IBM Studio

# %% [markdown]
# ## Alejandra Fernandez, desired occupation Data Science

# %% [markdown]
# *Data science was introduced to me last year through a webinar. I decided to learn more about Data science*

# %% [markdown]
# ###  Calculate 2 times 2 is?

# %%
2*2
# Out:
# 4

# %% [markdown]
# ![Image of dog](https://media.istockphoto.com/photos/dog-puppy-on-garden-picture-id1142412963)
#
#
#
#
# <https://www.markdownguide.org>
#
# | Header 1    | Header 2    | Header 3 |
# | ------------|:-----------:| --------:|
# | Cell        | Cell        | Cell     |
# | Cell        | Cell        | Cell     |
# | Cell        | Cell        | Cell     |
